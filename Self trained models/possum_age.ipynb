# %%
import pandas as pd
import numpy as np

# %%
# Generating the DataFrame
df = pd.read_csv('possum - Copy.csv')

df.pop('case')
col_gender = df.pop('sex')
col_name = df.pop('age')
df.insert(0, 'sex', col_gender)
df.insert(1, 'age', col_name)

nan_age = df[df['age'].isna()]
df.dropna(subset = ['age'], inplace = True)

X = df.iloc[:, 4:].values
y = df.iloc[:, 1].values
df
# Out:
#     sex  age  site    Pop  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     m  8.0     1    Vic     94.1    60.4      89.0   36.0      74.5
# 1     f  6.0     1    Vic     92.5    57.6      91.5   36.5      72.5
# 2     f  6.0     1    Vic     94.0    60.0      95.5   39.0      75.4
# 3     f  6.0     1    Vic     93.2    57.1      92.0   38.0      76.1
# 4     f  2.0     1    Vic     91.5    56.3      85.5   36.0      71.0
# ..   ..  ...   ...    ...      ...     ...       ...    ...       ...
# 99    m  1.0     7  other     89.5    56.0      81.5   36.5      66.0
# 100   m  1.0     7  other     88.6    54.7      82.5   39.0      64.4
# 101   f  6.0     7  other     92.4    55.0      89.0   38.0      63.5
# 102   m  4.0     7  other     91.5    55.2      82.5   36.5      62.9
# 103   f  3.0     7  other     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# ...

# %%
# Handling missing data
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer.fit(X)
X = imputer.transform(X)

# %%
# Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
# # Scaling the data
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = sc_X.fit_transform(X)
# y = sc_y.fit_transform(y.reshape(-1, 1))

# %%
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()
# regressor.fit(X_train, y_train)

# from sklearn.preprocessing import PolynomialFeatures 
# poly_reg = PolynomialFeatures(degree = 2)
# X_poly = poly_reg.fit_transform(X_train)
# lin_reg = LinearRegression()
# lin_reg.fit(X_poly, y_train)

# from sklearn.svm import SVR
# svm_regressor = SVR(kernel = 'rbf')
# svm_regressor.fit(X_train, y_train.ravel())

# from sklearn.tree import DecisionTreeRegressor
# regressorTree = DecisionTreeRegressor()
# regressorTree.fit(X_train, y_train)

# from sklearn.ensemble import RandomForestRegressor
# regressorForest = RandomForestRegressor(n_estimators = 100)
# regressorForest.fit(X_train, y_train)

# %%
# y_pred = regressor.predict(X_test)
# y_pred = lin_reg.predict(poly_reg.fit_transform(X_test))
# y_pred = sc_y.inverse_transform(svm_regressor.predict(sc_X.transform(X_test)).reshape(-1, 1))
# y_pred = svm_regressor.predict(X_test)
# y_pred = regressorTree.predict(X_test)
# y_pred = regressorForest.predict(X_test)

# %%
# from sklearn.metrics import r2_score
# print(r2_score(y_test, y_pred))
# print(y_test)
# print(y_pred)
